# %%
# Install micropip using pip from within the notebook.
import pip
await pip.install("micropip")

# Now you can import micropip
import micropip
await micropip.install("numpy")

import numpy as np  # Jetzt funktioniert es!
# Out:
# /usr/local/lib/python3.11/dist-packages/_distutils_hack/__init__.py:31: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2f21649eec41> in <cell line: 1>()
#       1 # Install micropip using pip from within the notebook.
#       2 import pip
# ----> 3 await pip.install("micropip")
#       4
#       5 # Now you can import micropip
#
# AttributeError: module 'pip' has no attribute 'install'
