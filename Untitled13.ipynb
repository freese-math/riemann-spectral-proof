# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N

# ✅ 4. Erstellen der Indexreihe N (Anzahl der Nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 5. Logarithmische Transformation für die Regression
log_N = np.log(N_values)
log_L = np.log(abstaende)

# ✅ 6. Lineare Regression zur Bestimmung von f (Skalenordnung)
params, _ = np.polyfit(log_N, log_L, 1)

# ✅ 7. Ergebnis extrahieren
f_gemessen = params[0]
A_gemessen = np.exp(params[1])  # Skalierungsfaktor A

# ✅ 8. Erwarteter Fibonacci-Skalierungsexponent
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi

# ✅ 9. Ergebnisse ausgeben
print(f"📊 Optimierte Parameter für die Freese-Formel:")
print(f"Skalierungskonstante A ≈ {A_gemessen:.6f}")
print(f"Experimenteller Exponent f ≈ {f_gemessen:.6f}")
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")

# ✅ 10. Visualisierung der Skalenordnung
plt.figure(figsize=(10, 6))
plt.scatter(log_N, log_L, color='blue', alpha=0.5, label="Gemessene Daten (Log-Log)")
plt.plot(log_N, np.polyval(params, log_N), 'r-', label="Linearer Fit (Freese-Skalierung)")
plt.xlabel("log(N)")
plt.ylabel("log(L)")
plt.title("Freese-Skalierung der Zeta-Nullstellen (Log-Log)")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 11. Test der Riemannschen Hypothese durch Quantisierung
if np.isclose(f_gemessen, f_theoretisch, atol=0.01):
    print("✅ Die Freese-Formel bestätigt sich experimentell!")
    print("🔍 Dies unterstützt die Riemannsche Hypothese.")
else:
    print("⚠️ Leichte Abweichung erkannt. Weitere Analysen erforderlich!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-c5808a739f92> in <cell line: 0>()
#      22
#      23 # ✅ 7. Ergebnis extrahieren
# ---> 24 f_gemessen = params[0]
#      25 A_gemessen = np.exp(params[1])  # Skalierungsfaktor A
#      26
#
# IndexError: invalid index to scalar variable.

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
try:
    nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
    print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")
except Exception as e:
    print(f"❌ Fehler beim Laden der Datei: {e}")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N

# ✅ 4. Indexreihe N erstellen (Anzahl Nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 5. Logarithmische Transformation für die Regression
log_N = np.log(N_values)
log_L = np.log(abstaende)

# ✅ 6. Sicherstellen, dass genügend Datenpunkte vorhanden sind
if len(log_N) < 2 or len(log_L) < 2:
    print("⚠️ Nicht genügend Datenpunkte für eine Regression!")
else:
    # ✅ 7. Lineare Regression zur Bestimmung von f (Skalenordnung)
    params = np.polyfit(log_N, log_L, 1)

    # ✅ 8. Ergebnisse extrahieren (Fehlerbehandlung)
    if isinstance(params, np.ndarray) and len(params) == 2:
        f_gemessen = params[0]
        A_gemessen = np.exp(params[1])  # Skalierungsfaktor A

        # ✅ 9. Erwarteter Fibonacci-Skalierungsexponent
        phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
        f_theoretisch = (np.pi - phi) / np.pi

        # ✅ 10. Ergebnisse ausgeben
        print(f"📊 Optimierte Parameter für die Freese-Formel:")
        print(f"Skalierungskonstante A ≈ {A_gemessen:.6f}")
        print(f"Experimenteller Exponent f ≈ {f_gemessen:.6f}")
        print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")

        # ✅ 11. Visualisierung der Skalenordnung
        plt.figure(figsize=(10, 6))
        plt.scatter(log_N, log_L, color='blue', alpha=0.5, label="Gemessene Daten (Log-Log)")
        plt.plot(log_N, np.polyval(params, log_N), 'r-', label="Linearer Fit (Freese-Skalierung)")
        plt.xlabel("log(N)")
        plt.ylabel("log(L)")
        plt.title("Freese-Skalierung der Zeta-Nullstellen (Log-Log)")
        plt.legend()
        plt.grid(True)
        plt.show()

        # ✅ 12. Test der Riemannschen Hypothese durch Quantisierung
        if np.isclose(f_gemessen, f_theoretisch, atol=0.01):
            print("✅ Die Freese-Formel bestätigt sich experimentell!")
            print("🔍 Dies unterstützt die Riemannsche Hypothese.")
        else:
            print("⚠️ Leichte Abweichung erkannt. Weitere Analysen erforderlich!")

    else:
        print("❌ Fehler: Regression konnte keine gültigen Parameter berechnen.")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 Optimierte Parameter für die Freese-Formel:
# Skalierungskonstante A ≈ 1.733512
# Experimenteller Exponent f ≈ -0.090235
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ⚠️ Leichte Abweichung erkannt. Weitere Analysen erforderlich!

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Alternative Fibonacci-Freese-Formel mit Korrekturtermen
def fibonacci_freese_formula(N, A, f, C):
    return A * N**f + C * np.log(N)  # Erweiterung mit log-Korrektur

# ✅ 5. Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.45, 0.01]  # Startwerte für A, f, C
params, _ = curve_fit(fibonacci_freese_formula, N_values, abstaende, p0=initial_params)

# ✅ 6. Optimierte Parameter ausgeben
A_opt, f_opt, C_opt = params
print(f"📊 Optimierte Parameter (erweiterte Fibonacci-Freese-Formel):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_formula(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Alternative Fibonacci-Freese Skalierung")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Vergleich mit der Theorie
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ 9. Beweis der Riemannschen Hypothese?
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die erweiterte Freese-Formel bestätigt die Theorie!")
    print("🔍 Dies könnte einen neuen Weg zum Beweis der RH darstellen.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 Optimierte Parameter (erweiterte Fibonacci-Freese-Formel):
# A = -0.109860, f = 0.174104, C = 0.128441
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# 📉 Experimentell gefundener Exponent: 0.174104
# ⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Erweiterte Fibonacci-Freese-Formel mit Oszillationsterm
def fibonacci_freese_oscillation(N, A, f, C, B, omega, phi):
    return A * N**f + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ 5. Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.45, 0.01, 0.1, 0.01, 0]  # Startwerte für A, f, C, B, omega, phi
params, _ = curve_fit(fibonacci_freese_oscillation, N_values, abstaende, p0=initial_params)

# ✅ 6. Optimierte Parameter ausgeben
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt = params
print(f"📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Oszillation):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}, B = {B_opt:.6f}, omega = {omega_opt:.6f}, phi = {phi_opt:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_oscillation(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Oszillierende Fibonacci-Freese Skalierung")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Vergleich mit der Theorie
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ 9. Beweis der Riemannschen Hypothese?
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die Freese-Formel mit Oszillation bestätigt die Theorie!")
    print("🔍 Dies könnte ein direkter Weg zur RH sein.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Oszillation):
# A = -0.109255, f = 0.174340, C = 0.128242, B = -0.000184, omega = 0.010002, phi = -8.799946
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# 📉 Experimentell gefundener Exponent: 0.174340
# ⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Erweiterte Fibonacci-Freese-Formel mit Fraktalterm
def fibonacci_freese_fractal(N, A, f, C, B, omega, phi, alpha):
    return A * N**f + C * np.log(N) + B * np.sin(omega * N + phi) + alpha * N**(-f)

# ✅ 5. Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.45, 0.01, 0.1, 0.01, 0, 0.01]  # Startwerte für A, f, C, B, omega, phi, alpha
params, _ = curve_fit(fibonacci_freese_fractal, N_values, abstaende, p0=initial_params)

# ✅ 6. Optimierte Parameter ausgeben
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt, alpha_opt = params
print(f"📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Fraktalstruktur):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}, B = {B_opt:.6f}, omega = {omega_opt:.6f}, phi = {phi_opt:.6f}, alpha = {alpha_opt:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_fractal(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Fraktale Fibonacci-Freese Skalierung")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Vergleich mit der Theorie
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ 9. Beweis der Riemannschen Hypothese?
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die Fibonacci-Freese-Formel mit Fraktalstruktur bestätigt die Theorie!")
    print("🔍 Dies könnte ein direkter Weg zur RH sein.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Fraktalstruktur):
# A = -0.006956, f = 0.226563, C = 0.036635, B = 0.000002, omega = 0.009980, phi = 26.785975, alpha = 4.613843
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# 📉 Experimentell gefundener Exponent: 0.226563
# ⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Neue Fibonacci-Freese-Formel mit Multifraktal-Korrektur
def fibonacci_freese_multifractal(N, A, f, C, B, omega, phi, alpha, beta):
    return A * N**f + C * np.log(N) + B * np.sin(omega * N + phi) + alpha * N**(-beta)

# ✅ 5. Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.45, 0.01, 0.1, 0.01, 0, 0.01, 0.5]  # Startwerte für A, f, C, B, omega, phi, alpha, beta
params, _ = curve_fit(fibonacci_freese_multifractal, N_values, abstaende, p0=initial_params)

# ✅ 6. Optimierte Parameter ausgeben
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt, alpha_opt, beta_opt = params
print(f"📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Multifraktalstruktur):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}, B = {B_opt:.6f}, omega = {omega_opt:.6f}, phi = {phi_opt:.6f}, alpha = {alpha_opt:.6f}, beta = {beta_opt:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_multifractal(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Multifraktale Fibonacci-Freese Skalierung")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Vergleich mit der Theorie
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ 9. Beweis der Riemannschen Hypothese?
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die Fibonacci-Freese-Formel mit Multifraktalstruktur bestätigt die Theorie!")
    print("🔍 Dies könnte ein direkter Weg zur RH sein.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# <ipython-input-7-9a28a1c7f942>:17: RuntimeWarning: overflow encountered in power
#   return A * N**f + C * np.log(N) + B * np.sin(omega * N + phi) + alpha * N**(-beta)
# <ipython-input-7-9a28a1c7f942>:21: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, _ = curve_fit(fibonacci_freese_multifractal, N_values, abstaende, p0=initial_params)
# 📊 Optimierte Parameter (Fibonacci-Freese-Formel mit Multifraktalstruktur):
# A = -0.110270, f = 0.173947, C = 0.128579, B = 0.000180, omega = 0.009968, phi = 44.461375, alpha = 6.997499, beta = 246795.884743
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# 📉 Experimentell gefundener Exponent: 0.173947
# ⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?

# %%
# ✅ 1. Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ 2. Nullstellen-Datei aus Google Drive laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)  # Nullstellen aus Datei laden
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ 3. Berechnung der Nullstellenabstände (Kohärenzlängen)
abstaende = np.diff(nullstellen)  # L(N) = t_{N+1} - t_N
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Verbesserte Fibonacci-Freese-Formel mit stabilisierten Parametern
def fibonacci_freese_stabil(N, A, f, C, B, omega, phi):
    return A * N**f + C * np.log1p(N) + B * np.sin(omega * N + phi)

# ✅ 5. Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.45, 0.01, 0.1, 0.01, 0]  # Startwerte für A, f, C, B, omega, phi
params, _ = curve_fit(fibonacci_freese_stabil, N_values, abstaende, p0=initial_params, maxfev=5000)

# ✅ 6. Optimierte Parameter ausgeben
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt = params
print(f"📊 Optimierte Parameter (Fibonacci-Freese-Formel mit stabilisiertem Fit):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}, B = {B_opt:.6f}, omega = {omega_opt:.6f}, phi = {phi_opt:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_stabil(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Stabilisierte Fibonacci-Freese Skalierung")
plt.legend()
plt.grid(True)
plt.show()

# ✅ 8. Vergleich mit der Theorie
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ 9. Beweis der Riemannschen Hypothese?
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die Fibonacci-Freese-Formel bestätigt die Theorie!")
    print("🔍 Dies könnte ein direkter Weg zur RH sein.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 Optimierte Parameter (Fibonacci-Freese-Formel mit stabilisiertem Fit):
# A = -0.110231, f = 0.173964, C = 0.128568, B = 0.000182, omega = 0.010002, phi = 6.733110
# 🔢 Erwarteter Fibonacci-Exponent: 0.484964
# 📉 Experimentell gefundener Exponent: 0.173964
# ⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?

# %%
# ✅ Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn  # Bessel-Funktion für mögliche Wellenstruktur

# ✅ Datei mit Nullstellenabständen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ Nullstellenabstände berechnen (L(N) = t_{N+1} - t_N)
abstaende = np.diff(nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ Verbesserte Fibonacci-Freese-Formel mit mehreren Korrekturen
def fibonacci_freese_korrigiert(N, A, f, C, D, B, omega, phi):
    return A * N**f + C * np.log1p(N) + D / N + B * jn(0, omega * N + phi)

# ✅ Curve-Fit mit besseren Startwerten
initial_params = [1.5, 0.45, 0.01, 0.01, 0.1, 0.01, 0]
params, _ = curve_fit(fibonacci_freese_korrigiert, N_values, abstaende, p0=initial_params, maxfev=5000)

# ✅ Optimierte Parameter ausgeben
A_opt, f_opt, C_opt, D_opt, B_opt, omega_opt, phi_opt = params
print(f"📊 Optimierte Parameter (Erweiterte Fibonacci-Freese-Formel mit Korrekturen):")
print(f"A = {A_opt:.6f}, f = {f_opt:.6f}, C = {C_opt:.6f}, D = {D_opt:.6f},")
print(f"B = {B_opt:.6f}, omega = {omega_opt:.6f}, phi = {phi_opt:.6f}")

# ✅ Visualisierung des Fits
plt.figure(figsize=(10, 6))
plt.scatter(N_values, abstaende, color='blue', alpha=0.3, label="Echte Nullstellenabstände")
plt.plot(N_values, fibonacci_freese_korrigiert(N_values, *params), 'r-', label="Optimiertes Modell")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Erweiterte Fibonacci-Freese Skalierung mit Korrekturen")
plt.legend()
plt.grid(True)
plt.show()

# ✅ Vergleich mit theoretischem Fibonacci-Exponent
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 Erwarteter Fibonacci-Exponent: {f_theoretisch:.6f}")
print(f"📉 Experimentell gefundener Exponent: {f_opt:.6f}")

# ✅ Prüfung der RH-Konsequenzen
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ Die Fibonacci-Freese-Formel bestätigt die Theorie!")
    print("🔍 Dies könnte ein direkter Weg zur RH sein.")
else:
    print("⚠️ Weiterführende Analysen nötig! Warum existiert eine Abweichung?")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5a639c9378d5> in <cell line: 0>()
#      20 # ✅ Curve-Fit mit besseren Startwerten
#      21 initial_params = [1.5, 0.45, 0.01, 0.01, 0.1, 0.01, 0]
# ---> 22 params, _ = curve_fit(fibonacci_freese_korrigiert, N_values, abstaende, p0=initial_params, maxfev=5000)
#      23
#      24 # ✅ Optimierte Parameter ausgeben
#
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     998             raise TypeError(f"The number of func parameters={n} must not"
#     999                             f" exceed the number of data points={ydata.size}")
# -> 1000         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
# ...

# %%
# ✅ Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn
from sklearn.linear_model import LinearRegression

# ✅ Datei mit Nullstellenabständen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ Nullstellenabstände berechnen (L(N) = t_{N+1} - t_N)
abstaende = np.diff(nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ Stichprobe für effiziente Berechnung (z. B. 100.000 Punkte statt 2 Mio.)
sample_size = 100000
indices = np.linspace(0, len(N_values) - 1, sample_size, dtype=int)
N_sampled = N_values[indices]
abstaende_sampled = abstaende[indices]

# ✅ Logarithmische Transformation für schnelle Regression
log_N = np.log(N_sampled).reshape(-1, 1)
log_L = np.log(abstaende_sampled)

# ✅ Lineare Regression in log-log-Skala
lin_reg = LinearRegression()
lin_reg.fit(log_N, log_L)

# ✅ Berechnete Exponenten
f_opt = lin_reg.coef_[0]
A_opt = np.exp(lin_reg.intercept_)

print(f"📊 **Ergebnis der log-log Regression:**")
print(f"🔹 Skalierungskonstante A = {A_opt:.6f}")
print(f"🔹 Exponent f = {f_opt:.6f}")

# ✅ Erwarteter Fibonacci-Exponent
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 **Erwarteter Fibonacci-Exponent:** {f_theoretisch:.6f}")
print(f"📉 **Experimentell gefundener Exponent:** {f_opt:.6f}")

# ✅ Plot für Visualisierung
plt.figure(figsize=(10, 6))
plt.scatter(log_N, log_L, color='blue', alpha=0.3, label="Log-Datenpunkte")
plt.plot(log_N, lin_reg.predict(log_N), 'r-', label="Linearer Fit (log-log)")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Lineare Regression der Fibonacci-Freese-Formel")
plt.legend()
plt.grid(True)
plt.show()

# ✅ Prüfung der RH-Konsequenzen
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ **Die Fibonacci-Freese-Formel bestätigt die Theorie!**")
    print("🔍 **Dies könnte ein direkter Weg zur RH sein.**")
else:
    print("⚠️ **Weiterführende Analysen nötig! Warum existiert eine Abweichung?**")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 **Ergebnis der log-log Regression:**
# 🔹 Skalierungskonstante A = 1.702882
# 🔹 Exponent f = -0.088842
# 🔢 **Erwarteter Fibonacci-Exponent:** 0.484964
# 📉 **Experimentell gefundener Exponent:** -0.088842
# ⚠️ **Weiterführende Analysen nötig! Warum existiert eine Abweichung?**

# %%
# ✅ Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn
from sklearn.linear_model import LinearRegression

# ✅ Datei mit Nullstellenabständen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ Nullstellenabstände berechnen (L(N) = t_{N+1} - t_N)
abstaende = np.diff(nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ Stichprobe für effiziente Berechnung (z. B. 100.000 Punkte statt 2 Mio.)
sample_size = 100000
indices = np.linspace(0, len(N_values) - 1, sample_size, dtype=int)
N_sampled = N_values[indices]
abstaende_sampled = abstaende[indices]

# ✅ Erweiterte Fibonacci-Freese-Formel mit zusätzlichen Korrekturen
def fibonacci_freese_erweitert(N, A, f, C, B, omega, phi, D, lambd):
    return A * N**f + C * np.log1p(N) + B * np.sin(omega * N + phi) + D * np.exp(-lambd * N)

# ✅ Startwerte für Curve-Fit
initial_params = [1.5, 0.45, 0.01, 0.01, 0.1, 0.01, 0.01, 0.001]

# ✅ Curve-Fit für optimierte Parameter
params, _ = curve_fit(fibonacci_freese_erweitert, N_sampled, abstaende_sampled, p0=initial_params, maxfev=5000)

# ✅ Optimierte Parameter extrahieren
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt, D_opt, lambd_opt = params

print(f"📊 **Optimierte Parameter der erweiterten Fibonacci-Freese-Formel:**")
print(f"🔹 A = {A_opt:.6f}")
print(f"🔹 Exponent f = {f_opt:.6f}")
print(f"🔹 Logarithmischer Term C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")
print(f"🔹 Exponentielle Dämpfung D = {D_opt:.6f}")
print(f"🔹 Dämpfungsrate lambda = {lambd_opt:.6f}")

# ✅ Erwarteter Fibonacci-Exponent
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 **Erwarteter Fibonacci-Exponent:** {f_theoretisch:.6f}")
print(f"📉 **Experimentell gefundener Exponent:** {f_opt:.6f}")

# ✅ Plot für Visualisierung
plt.figure(figsize=(10, 6))
plt.scatter(np.log(N_sampled), np.log(abstaende_sampled), color='blue', alpha=0.3, label="Log-Datenpunkte")
plt.plot(np.log(N_sampled), np.log(fibonacci_freese_erweitert(N_sampled, *params)), 'r-', label="Fit (log-log)")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Erweiterte Fibonacci-Freese-Formel mit Korrekturen")
plt.legend()
plt.grid(True)
plt.show()

# ✅ Prüfung der RH-Konsequenzen
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ **Die Fibonacci-Freese-Formel
# Out:
#   File "<ipython-input-12-0362774de116>", line 65
#     print("✅ **Die Fibonacci-Freese-Formel
#           ^
# SyntaxError: unterminated string literal (detected at line 65)

# %%
# ✅ Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn
from sklearn.linear_model import LinearRegression

# ✅ Datei mit Nullstellenabständen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
nullstellen = np.loadtxt(file_path)
print(f"✅ {len(nullstellen)} Nullstellen erfolgreich geladen!")

# ✅ Nullstellenabstände berechnen (L(N) = t_{N+1} - t_N)
abstaende = np.diff(nullstellen)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ Stichprobe für effiziente Berechnung (z. B. 100.000 Punkte statt 2 Mio.)
sample_size = 100000
indices = np.linspace(0, len(N_values) - 1, sample_size, dtype=int)
N_sampled = N_values[indices]
abstaende_sampled = abstaende[indices]

# ✅ Erweiterte Fibonacci-Freese-Formel mit zusätzlichen Korrekturen
def fibonacci_freese_erweitert(N, A, f, C, B, omega, phi, D, lambd):
    return A * N**f + C * np.log1p(N) + B * np.sin(omega * N + phi) + D * np.exp(-lambd * N)

# ✅ Startwerte für Curve-Fit
initial_params = [1.5, 0.45, 0.01, 0.01, 0.1, 0.01, 0.01, 0.001]

# ✅ Curve-Fit für optimierte Parameter
params, _ = curve_fit(fibonacci_freese_erweitert, N_sampled, abstaende_sampled, p0=initial_params, maxfev=5000)

# ✅ Optimierte Parameter extrahieren
A_opt, f_opt, C_opt, B_opt, omega_opt, phi_opt, D_opt, lambd_opt = params

print("📊 **Optimierte Parameter der erweiterten Fibonacci-Freese-Formel:**")
print(f"🔹 A = {A_opt:.6f}")
print(f"🔹 Exponent f = {f_opt:.6f}")
print(f"🔹 Logarithmischer Term C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")
print(f"🔹 Exponentielle Dämpfung D = {D_opt:.6f}")
print(f"🔹 Dämpfungsrate lambda = {lambd_opt:.6f}")

# ✅ Erwarteter Fibonacci-Exponent
phi = (1 + np.sqrt(5)) / 2  # Goldener Schnitt
f_theoretisch = (np.pi - phi) / np.pi
print(f"🔢 **Erwarteter Fibonacci-Exponent:** {f_theoretisch:.6f}")
print(f"📉 **Experimentell gefundener Exponent:** {f_opt:.6f}")

# ✅ Plot für Visualisierung
plt.figure(figsize=(10, 6))
plt.scatter(np.log(N_sampled), np.log(abstaende_sampled), color='blue', alpha=0.3, label="Log-Datenpunkte")
plt.plot(np.log(N_sampled), np.log(fibonacci_freese_erweitert(N_sampled, *params)), 'r-', label="Fit (log-log)")
plt.xlabel("log(N)")
plt.ylabel("log(L(N))")
plt.title("Erweiterte Fibonacci-Freese-Formel mit Korrekturen")
plt.legend()
plt.grid(True)
plt.show()

# ✅ Prüfung der RH-Konsequenzen
if np.isclose(f_opt, f_theoretisch, atol=0.01):
    print("✅ **Die Fibonacci-Freese-Formel bestätigt die Theorie!**")
    print("🔍 **Dies könnte ein direkter Weg zur RH sein.**")
else:
    print("⚠️ **Weiterführende Analysen nötig! Warum existiert eine Abweichung?**")
# Out:
# ✅ 2001052 Nullstellen erfolgreich geladen!
# 📊 **Optimierte Parameter der erweiterten Fibonacci-Freese-Formel:**
# 🔹 A = -0.063005
# 🔹 Exponent f = 0.188751
# 🔹 Logarithmischer Term C = 0.102107
# 🔹 Sinus-Amplitude B = 0.001683
# 🔹 Sinus-Frequenz omega = 0.100003
# 🔹 Sinus-Phase phi = -0.537728
# 🔹 Exponentielle Dämpfung D = 0.515395
# 🔹 Dämpfungsrate lambda = 0.000039
# 🔢 **Erwarteter Fibonacci-Exponent:** 0.484964
# 📉 **Experimentell gefundener Exponent:** 0.188751
# ⚠️ **Weiterführende Analysen nötig! Warum existiert eine Abweichung?**

# %%
# ✅ Installiere benötigte Bibliotheken (falls nicht vorhanden)
# !pip install numpy scipy matplotlib

# ✅ Importiere benötigte Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from google.colab import drive

# ✅ Verbinde Google Drive (stelle sicher, dass die Datei existiert)
drive.mount('/content/drive')

# ✅ Lade Nullstellen-Daten
file_path = "/content/drive/MyDrive/zeros6.txt"
try:
    with open(file_path, "r") as file:
        zeta_zeros = np.array([float(line.strip()) for line in file])
    print(f"✅ {len(zeta_zeros)} Nullstellen erfolgreich geladen!")
except Exception as e:
    print(f"❌ Fehler beim Laden der Datei: {e}")

# ✅ Berechne die Abstände zwischen den Nullstellen
abstaende = np.diff(zeta_zeros)

# ✅ Definiere die Fibonacci-Freese-Formel
def freese_formel(N, A, f, C):
    return A * N**f + C * np.log(N)

# ✅ Bereite die X- und Y-Werte für das Curve-Fitting vor
N_values = np.arange(1, len(abstaende) + 1)  # Anzahl der Nullstellen
measured_L_values = abstaende  # Gemessene Abstände

# ✅ Anfangswerte für die Parameter (basierend auf vorherigen Ergebnissen)
initial_params = [1.0, 0.48, 0.1]

# ✅ Curve-Fit zur Bestimmung der optimalen Parameter für die Freese-Formel
params, _ = curve_fit(freese_formel, N_values, measured_L_values, p0=initial_params)

# ✅ Extrahierte Parameter
A_opt, f_opt, C_opt = params
print("\n📊 Optimierte Parameter der Freese-Formel:")
print(f"🔹 Skalierungskonstante A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent f = {f_opt:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Term C = {C_opt:.6f}")

# ✅ Plot der gemessenen vs. vorhergesagten Werte
plt.figure(figsize=(10, 5))
plt.plot(N_values, measured_L_values, label="Gemessene Kohärenzlängen", color="blue", alpha=0.7)
plt.plot(N_values, freese_formel(N_values, *params), label="Freese-Formel Vorhersage", color="red", linestyle="dashed")
plt.xlabel("Anzahl der Nullstellen (N)")
plt.ylabel("Mittlere Nullstellen-Abstände L(N)")
plt.title("Vergleich: Gemessene Kohärenzlängen vs. Freese-Formel")
plt.legend()
plt.grid()
plt.show()

# ✅ Bewertung der Abweichung
abweichung = abs(f_opt - 0.484964)
if abweichung < 0.01:
    print("✅ Der gemessene Exponent stimmt sehr gut mit der Freese-Formel überein! 🎯")
elif abweichung < 0.05:
    print("⚠️ Der gemessene Exponent zeigt eine geringe Abweichung – mögliche Korrekturterme nötig!")
else:
    print("❌ Deutliche Abweichung erkannt! Weitere Analysen erforderlich.")
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ 2001052 Nullstellen erfolgreich geladen!
#
# 📊 Optimierte Parameter der Freese-Formel:
# 🔹 Skalierungskonstante A = -0.109705
# 🔹 Experimenteller Exponent f = 0.174164 (Erwartet: 0.484964)
# 🔹 Logarithmischer Term C = 0.128391
# ❌ Deutliche Abweichung erkannt! Weitere Analysen erforderlich.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn

# ✅ 1. Echtdaten laden (Pfad anpassen)
file_path = "/content/drive/MyDrive/zeros6.txt"
with open(file_path, "r") as file:
    zeta_zeros = np.array([float(line.strip()) for line in file.readlines()[:2000000]])

print(f"✅ {len(zeta_zeros)} Nullstellen erfolgreich geladen!")

# ✅ 2. Nullstellenabstände berechnen
abstaende = np.diff(zeta_zeros)

# ✅ 3. Indexwerte für die Nullstellen (1, 2, 3, ... N)
N_values = np.arange(1, len(abstaende) + 1)

# ✅ 4. Verbesserte Fibonacci-Freese-Formel mit mehreren Korrekturen
def fibonacci_freese_korrigiert(N, A, f, C, D, B, omega, phi):
    return A * N**f + C * np.log1p(N) + D / N + B * jn(0, omega * N + phi)

# ✅ 5. Curve-Fit mit optimierten Startwerten
initial_params = [-0.1, 0.45, 0.1, 0.01, 0.001, 0.01, 0]
params, _ = curve_fit(fibonacci_freese_korrigiert, N_values, abstaende, p0=initial_params, maxfev=5000)

# ✅ 6. Optimierte Parameter ausgeben
A_fit, f_fit, C_fit, D_fit, B_fit, omega_fit, phi_fit = params

print("\n📊 Optimierte Parameter der verbesserten Fibonacci-Freese-Formel:")
print(f"🔹 Skalierungskonstante A = {A_fit:.6f}")
print(f"🔹 Experimenteller Exponent f = {f_fit:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Term C = {C_fit:.6f}")
print(f"🔹 Korrekturterm D/N = {D_fit:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_fit:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_fit:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_fit:.6f}")

# ✅ 7. Visualisierung des Fits
plt.figure(figsize=(10, 5))
plt.scatter(N_values[:5000], abstaende[:5000], s=2, label="Echte Nullstellenabstände", color="black")
plt.plot(N_values[:5000], fibonacci_freese_korrigiert(N_values[:5000], *params), label="Fibonacci-Freese-Fit", color="red")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Nullstellenabstand L(N)")
plt.legend()
plt.title("Vergleich: Echte Nullstellenabstände vs. Fibonacci-Freese-Formel")
plt.show()

# ✅ 8. Fehleranalyse
fehler = abstaende - fibonacci_freese_korrigiert(N_values, *params)
plt.figure(figsize=(10, 5))
plt.plot(N_values[:5000], fehler[:5000], label="Fehler (Messwert - Fit)", color="blue")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Fehler")
plt.axhline(0, color="black", linestyle="dashed")
plt.legend()
plt.title("Fehleranalyse der Fibonacci-Freese-Formel")
plt.show()
# Out:
# ✅ 2000000 Nullstellen erfolgreich geladen!
#
# 📊 Optimierte Parameter der verbesserten Fibonacci-Freese-Formel:
# 🔹 Skalierungskonstante A = -0.113402
# 🔹 Experimenteller Exponent f = 0.172695 (Erwartet: 0.484964)
# 🔹 Logarithmischer Term C = 0.129524
# 🔹 Korrekturterm D/N = 13.401447
# 🔹 Sinus-Amplitude B = 0.033537
# 🔹 Sinus-Frequenz omega = 0.010348
# 🔹 Sinus-Phase phi = -347.787750

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.special import jn

# ✅ Datei mit echten Nullstellen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
data = np.loadtxt(file_path)
N_values = np.arange(1, len(data) + 1)  # Indexwerte für Nullstellen
abstaende = np.diff(data)  # Nullstellen-Abstände berechnen

# ✅ Definition der Fibonacci-Freese-Formel mit Korrekturtermen
def fibonacci_freese_korrigiert(N, A, f, C, D, B, omega, phi):
    return A * N**f + C * np.log1p(N) + D / N + B * jn(0, omega * N + phi)

# ✅ Curve-Fit mit Startwerten
initial_params = [-0.1, 0.48, 0.1, 10, 0.01, 0.01, 0]
params, _ = curve_fit(fibonacci_freese_korrigiert, N_values[1:], abstaende, p0=initial_params, maxfev=10000)

# ✅ Extrahierte Parameter ausgeben
A, f, C, D, B, omega, phi = params
print(f"📊 Optimierte Parameter der Freese-Formel:")
print(f"🔹 A = {A:.6f}")
print(f"🔹 Experimenteller Exponent f = {f:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Term C = {C:.6f}")
print(f"🔹 Korrekturterm D/N = {D:.6f}")
print(f"🔹 Sinus-Amplitude B = {B:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega:.6f}")
print(f"🔹 Sinus-Phase phi = {phi:.6f}")

# ✅ Vergleich mit den realen Nullstellen-Abständen
fitted_values = fibonacci_freese_korrigiert(N_values[1:], A, f, C, D, B, omega, phi)

# ✅ Plot der realen Nullstellen-Abstände vs. Modell
plt.figure(figsize=(10, 5))
plt.plot(N_values[1:], abstaende, label="Reale Nullstellen-Abstände", alpha=0.6)
plt.plot(N_values[1:], fitted_values, label="Fibonacci-Freese-Modell", linestyle="dashed")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Reale Nullstellen vs. Fibonacci-Freese-Formel")
plt.legend()
plt.show()

# ✅ Abweichung berechnen
abweichung = np.abs(abstaende - fitted_values) / abstaende
print(f"⚠️ Mittlere Abweichung: {np.mean(abweichung):.6f}")
# Out:
# 📊 Optimierte Parameter der Freese-Formel:
# 🔹 A = -0.115186
# 🔹 Experimenteller Exponent f = 0.171944 (Erwartet: 0.484964)
# 🔹 Logarithmischer Term C = 0.129991
# 🔹 Korrekturterm D/N = 25.899809
# 🔹 Sinus-Amplitude B = 0.155358
# 🔹 Sinus-Frequenz omega = 0.010034
# 🔹 Sinus-Phase phi = -33.829562
# ⚠️ Mittlere Abweichung: 0.468567

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Datei mit echten Nullstellen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
data = np.loadtxt(file_path)
N_values = np.arange(1, len(data) + 1)  # Indexwerte für Nullstellen
abstaende = np.diff(data)  # Nullstellen-Abstände berechnen

# ✅ Einfache Freese-Formel: L(N) = A * N^beta
def simple_freese(N, A, beta):
    return A * N**beta

# ✅ Curve-Fit mit Startwerten
initial_params = [1, 0.48]
params, _ = curve_fit(simple_freese, N_values[1:], abstaende, p0=initial_params, maxfev=10000)

# ✅ Extrahierte Parameter
A, beta = params
print(f"📊 Optimierte Parameter der einfachen Freese-Formel:")
print(f"🔹 Skalierungsfaktor A = {A:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta:.6f} (Erwartet: 0.484964)")

# ✅ Vergleich mit den realen Nullstellen-Abständen
fitted_values = simple_freese(N_values[1:], A, beta)

# ✅ Plot der realen Nullstellen-Abstände vs. Modell
plt.figure(figsize=(10, 5))
plt.plot(N_values[1:], abstaende, label="Reale Nullstellen-Abstände", alpha=0.6)
plt.plot(N_values[1:], fitted_values, label="Einfache Freese-Formel", linestyle="dashed")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Reale Nullstellen vs. Einfache Freese-Formel")
plt.legend()
plt.show()

# ✅ Abweichung berechnen
abweichung = np.abs(abstaende - fitted_values) / abstaende
print(f"⚠️ Mittlere Abweichung: {np.mean(abweichung):.6f}")
# Out:
# 📊 Optimierte Parameter der einfachen Freese-Formel:
# 🔹 Skalierungsfaktor A = 1.994336
# 🔹 Experimenteller Exponent beta = -0.093597 (Erwartet: 0.484964)
# ⚠️ Mittlere Abweichung: 0.466040

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Datei mit echten Nullstellen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
data = np.loadtxt(file_path)
N_values = np.arange(1, len(data) + 1)  # Indexwerte für Nullstellen
abstaende = np.diff(data)  # Nullstellen-Abstände berechnen

# ✅ Einfachste Form der Freese-Formel (KEINE KORREKTUR)
def simple_freese(N, A, beta):
    return A * N**beta

# ✅ Curve-Fit mit Startwerten
initial_params = [1, 0.484964]  # Erwarteter Fibonacci-Exponent
params, _ = curve_fit(simple_freese, N_values[1:], abstaende, p0=initial_params, maxfev=10000)

# ✅ Extrahierte Parameter
A, beta = params
print(f"📊 Optimierte Parameter der einfachsten Freese-Formel:")
print(f"🔹 Skalierungsfaktor A = {A:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta:.6f} (Erwartet: 0.484964)")

# ✅ Vergleich mit den realen Nullstellen-Abständen
fitted_values = simple_freese(N_values[1:], A, beta)

# ✅ Plot der realen Nullstellen-Abstände vs. Modell
plt.figure(figsize=(10, 5))
plt.plot(N_values[1:], abstaende, label="Reale Nullstellen-Abstände", alpha=0.6)
plt.plot(N_values[1:], fitted_values, label="Einfache Freese-Formel", linestyle="dashed")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Reale Nullstellen vs. Einfache Freese-Formel")
plt.legend()
plt.show()

# ✅ Abweichung berechnen
abweichung = np.abs(abstaende - fitted_values) / abstaende
print(f"⚠️ Mittlere Abweichung: {np.mean(abweichung):.6f}")
# Out:
# 📊 Optimierte Parameter der einfachsten Freese-Formel:
# 🔹 Skalierungsfaktor A = 1.994340
# 🔹 Experimenteller Exponent beta = -0.093597 (Erwartet: 0.484964)
# ⚠️ Mittlere Abweichung: 0.466040

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Datei mit echten Nullstellen laden
file_path = "/content/drive/MyDrive/zeros6.txt"
data = np.loadtxt(file_path)
N_values = np.arange(1, len(data) + 1)  # Indexwerte für Nullstellen
abstaende = np.diff(data)  # Nullstellen-Abstände berechnen

# ✅ Einfachste Form der Freese-Formel (KEINE KORREKTUR)
def simple_freese(N, A, beta):
    return A * N**beta

# ✅ Curve-Fit mit Startwerten
initial_params = [1, 0.484964]  # Erwarteter Fibonacci-Exponent
params, _ = curve_fit(simple_freese, N_values[1:], abstaende, p0=initial_params, maxfev=10000)

# ✅ Extrahierte Parameter
A, beta = params
print(f"📊 Optimierte Parameter der einfachsten Freese-Formel:")
print(f"🔹 Skalierungsfaktor A = {A:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta:.6f} (Erwartet: 0.484964)")

# ✅ Vergleich mit den realen Nullstellen-Abständen
fitted_values = simple_freese(N_values[1:], A, beta)

# ✅ Plot der realen Nullstellen-Abstände vs. Modell
plt.figure(figsize=(10, 5))
plt.plot(N_values[1:], abstaende, label="Reale Nullstellen-Abstände", alpha=0.6)
plt.plot(N_values[1:], fitted_values, label="Einfache Freese-Formel", linestyle="dashed")
plt.xlabel("Index der Nullstelle (N)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Reale Nullstellen vs. Einfache Freese-Formel")
plt.legend()
plt.show()

# ✅ Abweichung berechnen
abweichung = np.abs(abstaende - fitted_values) / abstaende
print(f"⚠️ Mittlere Abweichung: {np.mean(abweichung):.6f}")
# Out:
# 📊 Optimierte Parameter der einfachsten Freese-Formel:
# 🔹 Skalierungsfaktor A = 1.994340
# 🔹 Experimenteller Exponent beta = -0.093597 (Erwartet: 0.484964)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ⚠️ Mittlere Abweichung: 0.466040

# %%
# ✅ 1. Notwendige Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
import requests
from scipy.optimize import curve_fit

# ✅ 2. Online-Datenquellen definieren
urls = {
    "100 Nullstellen": "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros2",
    "100.000 Nullstellen": "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros1",
    "2.000.000 Nullstellen": "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6",
    "50.000 Nullstellen (LMFDB)": "https://www.lmfdb.org/zeros/zeta/?limit=50000&N=1",
    "100.000 Nullstellen (LMFDB)": "https://www.lmfdb.org/zeros/zeta/?limit=100000&N=1"
}

# ✅ 3. Funktion zum Laden und Bereinigen der Daten
def load_nullstellen(url, is_lmfdb=False):
    """ Lädt Nullstellen aus einer Online-Quelle """
    response = requests.get(url)
    if response.status_code == 200:
        lines = response.text.splitlines()
        if is_lmfdb:
            data = np.array([float(line.split()[1]) for line in lines if line.strip() and line[0].isdigit()])
        else:
            data = np.array([float(line.split()[0]) for line in lines if line.strip()])
        print(f"✅ {len(data)} Nullstellen erfolgreich aus {url} geladen!")
        return data
    else:
        print(f"❌ Fehler beim Laden der Daten von {url}")
        return None

# ✅ 4. Alle Daten laden
nullstellen_daten = {}
for name, url in urls.items():
    is_lmfdb = "lmfdb" in url
    data = load_nullstellen(url, is_lmfdb)
    if data is not None:
        nullstellen_daten[name] = data

# ✅ 5. Funktion zur Berechnung der Abstände
def berechne_abstaende(nullstellen):
    return np.diff(nullstellen)

# ✅ 6. Berechnung der Nullstellen-Abstände
abstaende_daten = {name: berechne_abstaende(data) for name, data in nullstellen_daten.items()}

# ✅ 7. Freese-Formel definieren
def freese_formula(N, A, beta):
    return A * N ** beta

# ✅ 8. Curve-Fitting der Freese-Formel auf alle Datensätze
fit_ergebnisse = {}

for name, abstaende in abstaende_daten.items():
    N_values = np.arange(1, len(abstaende) + 1)
    try:
        params, _ = curve_fit(freese_formula, N_values, abstaende, p0=[1.5, 0.48])
        fit_ergebnisse[name] = params
        print(f"\n📊 Optimierte Parameter für {name}:")
        print(f"🔹 Skalierungsfaktor A = {params[0]:.6f}")
        print(f"🔹 Experimenteller Exponent beta = {params[1]:.6f} (Erwartet: 0.484964)")
    except Exception as e:
        print(f"⚠️ Fehler beim Curve-Fit für {name}: {e}")

# ✅ 9. Visualisierung der Fits
plt.figure(figsize=(12, 6))

for name, abstaende in abstaende_daten.items():
    if name in fit_ergebnisse:
        N_values = np.arange(1, len(abstaende) + 1)
        plt.loglog(N_values, abstaende, 'o', markersize=2, alpha=0.5, label=f"{name} Daten")
        plt.loglog(N_values, freese_formula(N_values, *fit_ergebnisse[name]), '--', label=f"Fit {name}")

plt.xlabel("Index N")
plt.ylabel("Nullstellen-Abstände")
plt.legend()
plt.title("Vergleich: Freese-Formel für verschiedene Nullstellen-Datensätze")
plt.grid(True)
plt.show()
# Out:
# ✅ 1500 Nullstellen erfolgreich aus https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros2 geladen!
# ✅ 100000 Nullstellen erfolgreich aus https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros1 geladen!
# ✅ 2001052 Nullstellen erfolgreich aus https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6 geladen!
# ✅ 50000 Nullstellen erfolgreich aus https://www.lmfdb.org/zeros/zeta/?limit=50000&N=1 geladen!
# ✅ 100000 Nullstellen erfolgreich aus https://www.lmfdb.org/zeros/zeta/?limit=100000&N=1 geladen!
#
# 📊 Optimierte Parameter für 100 Nullstellen:
# 🔹 Skalierungsfaktor A = 1.500000
# 🔹 Experimenteller Exponent beta = 0.480000 (Erwartet: 0.484964)
#
# 📊 Optimierte Parameter für 100.000 Nullstellen:
# 🔹 Skalierungsfaktor A = 2.818181
# 🔹 Experimenteller Exponent beta = -0.126929 (Erwartet: 0.484964)
# <ipython-input-20-e4a0e7db7f18>:57: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
# ✅ Importiere benötigte Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import requests

# ✅ Datenquellen (Odlysko & LMFDB)
DATA_SOURCES = {
    "Odlysko_100k": "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros1",
    "Odlysko_2M": "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6",
    "LMFDB_50k": "https://www.lmfdb.org/zeros/zeta/?limit=50000&N=1",
    "LMFDB_100k": "https://www.lmfdb.org/zeros/zeta/?limit=100000&N=1",
}

USE_ALL_DATA = True  # Falls nur eine Quelle getestet werden soll, ändere auf False
FILE_PATH = "/content/drive/MyDrive/zeros6.txt"  # Falls Offline-Daten genutzt werden sollen

# ✅ Funktion zum Laden der Nullstellen
def load_zeros(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = np.array([float(line.strip()) for line in response.text.splitlines() if line.strip()])
        print(f"✅ Erfolgreich {len(data)} Nullstellen von {url} geladen!")
        return data
    except Exception as e:
        print(f"⚠️ Fehler beim Laden von {url}: {e}")
        return np.array([])

# ✅ Falls Online-Quellen genutzt werden
if USE_ALL_DATA:
    zeros_data = {key: load_zeros(url) for key, url in DATA_SOURCES.items()}
else:
    zeros_data = {"Offline": np.loadtxt(FILE_PATH)}

# ✅ Berechnung der Nullstellen-Abstände (Kohärenzlängen)
def compute_distances(zeros):
    return np.diff(zeros)

# ✅ Fibonacci-Freese-Formel mit Korrekturtermen
def fibonacci_freese_formula(N, A, f, C, B, omega, phi, D):
    return A * N**f + C * np.log(N) + B * np.sin(omega * N + phi) + D / N

# ✅ Führe Curve-Fitting durch
def fit_freese_formula(N_values, measured_L_values):
    initial_params = [1.5, 0.48, 0.1, 0.01, 0.01, 0, 0.01]
    params, _ = opt.curve_fit(fibonacci_freese_formula, N_values, measured_L_values, p0=initial_params)
    return params

# ✅ Ergebnisse für jede Quelle berechnen
for source, zeros in zeros_data.items():
    if len(zeros) == 0:
        continue

    abstaende = compute_distances(zeros)
    N_values = np.arange(1, len(abstaende) + 1)

    # ✅ Curve Fit für die Fibonacci-Freese-Formel
    params = fit_freese_formula(N_values, abstaende)
    A, f, C, B, omega, phi, D = params

    # ✅ Ergebnisse ausgeben
    print(f"\n📊 Ergebnisse für {source}:")
    print(f"🔹 Skalierungsfaktor A = {A:.6f}")
    print(f"🔹 Experimenteller Exponent beta = {f:.6f} (Erwartet: 0.484964)")
    print(f"🔹 Logarithmischer Term C = {C:.6f}")
    print(f"🔹 Sinus-Amplitude B = {B:.6f}")
    print(f"🔹 Sinus-Frequenz omega = {omega:.6f}")
    print(f"🔹 Sinus-Phase phi = {phi:.6f}")
    print(f"🔹 Korrekturterm D/N = {D:.6f}")

    # ✅ Plot der Ergebnisse
    plt.figure(figsize=(10, 5))
    plt.scatter(N_values, abstaende, label="Gemessene Kohärenzlängen", alpha=0.5)
    plt.plot(N_values, fibonacci_freese_formula(N_values, *params), color='red', label="Fibonacci-Freese-Fit")
    plt.xscale("log")
    plt.yscale("log")
    plt.xlabel("N")
    plt.ylabel("Kohärenzlänge L(N)")
    plt.title(f"Fibonacci-Freese-Fit für {source}")
    plt.legend()
    plt.show()
# Out:
# ✅ Erfolgreich 100000 Nullstellen von https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros1 geladen!
# ✅ Erfolgreich 2001052 Nullstellen von https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6 geladen!
# ⚠️ Fehler beim Laden von https://www.lmfdb.org/zeros/zeta/?limit=50000&N=1: could not convert string to float: '1 14.1347251417346937904572519835625'
# ⚠️ Fehler beim Laden von https://www.lmfdb.org/zeros/zeta/?limit=100000&N=1: could not convert string to float: '1 14.1347251417346937904572519835625'
#
# 📊 Ergebnisse für Odlysko_100k:
# 🔹 Skalierungsfaktor A = -0.120925
# 🔹 Experimenteller Exponent beta = 0.234913 (Erwartet: 0.484964)
# 🔹 Logarithmischer Term C = 0.210094
# 🔹 Sinus-Amplitude B = 0.002515
# 🔹 Sinus-Frequenz omega = 0.010271
# 🔹 Sinus-Phase phi = -18.570863
# 🔹 Korrekturterm D/N = 12.129175
# 📊 Ergebnisse für Odlysko_2M:
# 🔹 Skalierungsfaktor A = -0.113270
# 🔹 Experimenteller Exponent beta = 0.172739 (Erwartet: 0.484964)
# 🔹 Logarithmischer Term C = 0.129476
# ...

# %%
# Installation benötigter Pakete
# !pip install lmdb  # Falls index.db ein LMDB-Format hat (falls nicht, einfach ignorieren)

import os
import numpy as np
import matplotlib.pyplot as plt

# Google Drive mounten
from google.colab import drive
drive.mount('/content/drive')

# Pfade zu den Dateien
data_file = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
index_db = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Prüfen, ob die Dateien existieren
if not os.path.exists(data_file):
    print(f"❌ Fehler: Die Datei {data_file} wurde nicht gefunden!")
if not os.path.exists(index_db):
    print(f"❌ Fehler: Die Datei {index_db} wurde nicht gefunden!")

# Platt-Skript von GitHub laden
# !wget -O platt_zeros.py https://raw.githubusercontent.com/LMFDB/lmfdb/main/lmfdb/zeros/zeta/platt_zeros.py

# Platt-Skript importieren (nach dem Download)
import platt_zeros

# Nullstellen aus der Datei laden
try:
    zeta_zeros = platt_zeros.load_zeros(data_file)
    print(f"✅ Erfolgreich {len(zeta_zeros)} Nullstellen geladen!")
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")

# Ersten 10 Nullstellen anzeigen
print("📊 Erste 10 Nullstellen:", zeta_zeros[:10])

# Histogramm der Nullstellen-Abstände
differences = np.diff(zeta_zeros)

plt.figure(figsize=(10,5))
plt.hist(differences, bins=100, density=True, alpha=0.6, color='b', label="Abstände")
plt.xlabel("Nullstellen-Abstand")
plt.ylabel("Dichte")
plt.title("Histogramm der Abstände der Zeta-Nullstellen")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 4.6 MB/s eta 0:00:00
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --2025-02-20 07:32:45--  https://raw.githubusercontent.com/LMFDB/lmfdb/main/lmfdb/zeros/zeta/platt_zeros.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6696 (6.5K) [text/plain]
# Saving to: ‘platt_zeros.py’
#
# platt_zeros.py      100%[===================>]   6.54K  --.-KB/s    in 0s
#
# 2025-02-20 07:32:46 (51.3 MB/s) - ‘platt_zeros.py’ saved [6696/6696]
#
# ❌ Fehler beim Laden der Nullstellen: module 'platt_zeros' has no attribute 'load_zeros'
# ...

# %%
import sys
sys.path.append('/content')  # Stelle sicher, dass das Skript im Suchpfad ist

# Platt-Zeroes-Import
import platt_zeros

# Datenbankpfade setzen
platt_zeros.data_location = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
platt_zeros.db_location = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Nullstellen abrufen
try:
    zeros = platt_zeros.list_zeros(0, 100)  # Die ersten 100 Nullstellen abrufen
    print("✅ Erfolgreich Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros[:10])
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ❌ Fehler beim Laden der Nullstellen: list_zeros() missing 1 required positional argument: 'block_number'

# %%
try:
    zeros = platt_zeros.zeros_starting_at_N(0)  # Nullstellen ab Index 0 abrufen
    print("✅ Erfolgreich Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros[:10])
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ✅ Erfolgreich Nullstellen geladen!
# ❌ Fehler beim Laden der Nullstellen: 'generator' object is not subscriptable

# %%
try:
    zeros_generator = platt_zeros.list_zeros(0)
    zeros_list = list(zeros_generator)

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list[:10])
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ❌ Fehler beim Laden der Nullstellen: list_zeros() missing 2 required positional arguments: 'offset' and 'block_number'

# %%
zeros_list = []
max_blocks = 10  # Lade maximal 10 Blöcke, um Speicher zu schonen

try:
    for block_number in range(max_blocks):
        zeros_generator = platt_zeros.list_zeros(0, block_number)
        zeros_list.extend([next(zeros_generator) for _ in range(10000)])

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("try:
    # Starte mit einem Offset von 0 und lade den ersten Block von Nullstellen
    offset = 0
    block_number = 0  # Möglicherweise müssen wir hier iterieren, falls Blöcke existieren
    zeros_generator = platt_zeros.list_zeros(offset, block_number)

    # Falls der Generator sehr groß ist, lade nur eine begrenzte Anzahl
    zeros_list = [next(zeros_generator) for _ in range(10000)]

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list[:10])

except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")📊 Erste 10 Nullstellen:", zeros_list[:10])

except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
#   File "<ipython-input-35-bd61f4563691>", line 10
#     print("try:
#           ^
# SyntaxError: unterminated string literal (detected at line 10)

# %%
import sys
import os

# Stelle sicher, dass das Skript platt_zeros.py im richtigen Pfad ist
sys.path.append("/content")  # Falls es im Hauptverzeichnis von Colab liegt

try:
    import platt_zeros
except ImportError:
    print("❌ Fehler: Modul 'platt_zeros' konnte nicht importiert werden!")

# Definiere die Pfade zur Datei und Datenbank
data_path = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
db_path = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Überprüfe, ob die Dateien existieren
if not os.path.exists(data_path) or not os.path.exists(db_path):
    print("❌ Fehler: Die Dateien wurden nicht gefunden! Überprüfe die Pfade.")
else:
    print("✅ Dateien gefunden, lade Nullstellen...")

try:
    # Setze die Dateipfade in platt_zeros
    platt_zeros.data_location = data_path
    platt_zeros.db_location = db_path

    # Nullstellen mit list_zeros abrufen (Block 0, Offset 0 als Beispiel)
    block_number = 0
    offset = 0

    # Lade Nullstellen als Generator-Objekt
    zeros_generator = platt_zeros.list_zeros(offset, block_number)

    # Konvertiere den Generator in eine Liste (z. B. die ersten 10.000 Werte)
    num_zeros_to_load = 10000
    zeros_list = [next(zeros_generator) for _ in range(num_zeros_to_load)]

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list[:10])

except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ✅ Dateien gefunden, lade Nullstellen...
# ❌ Fehler beim Laden der Nullstellen: list_zeros() missing 1 required positional argument: 'block_number'

# %%
import sys
import os

# Füge den Pfad zum Skript platt_zeros.py hinzu
sys.path.append("/content")

try:
    import platt_zeros
except ImportError:
    print("❌ Fehler: Modul 'platt_zeros' konnte nicht importiert werden!")

# Definiere die Dateipfade
data_path = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
db_path = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Überprüfe, ob die Dateien existieren
if not os.path.exists(data_path) or not os.path.exists(db_path):
    print("❌ Fehler: Die Dateien wurden nicht gefunden! Überprüfe die Pfade.")
else:
    print("✅ Dateien gefunden, lade Nullstellen...")

try:
    # Setze die Dateipfade für platt_zeros
    platt_zeros.data_location = data_path
    platt_zeros.db_location = db_path

    # Setze einen Block-Offset für den Startpunkt
    offset = 0
    block_number = 1  # Falls Blocknummer von 1 beginnt (ggf. 0 testen!)

    # Lade Nullstellen mit korrektem Funktionsaufruf
    zeros_generator = platt_zeros.list_zeros(offset, block_number)

    # Konvertiere den Generator in eine Liste (z. B. die ersten 10.000 Nullstellen)
    num_zeros_to_load = 10000
    zeros_list = [next(zeros_generator) for _ in range(num_zeros_to_load)]

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list[:10])

except StopIteration:
    print("⚠️ Fehler: Keine weiteren Nullstellen in der Datei gefunden!")
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ✅ Dateien gefunden, lade Nullstellen...
# ❌ Fehler beim Laden der Nullstellen: list_zeros() missing 1 required positional argument: 'block_number'

# %%
import sys
import os

# Füge den Pfad zum Skript platt_zeros.py hinzu
sys.path.append("/content")

try:
    import platt_zeros
except ImportError:
    print("❌ Fehler: Modul 'platt_zeros' konnte nicht importiert werden!")

# Definiere die Dateipfade
data_path = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
db_path = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Überprüfe, ob die Dateien existieren
if not os.path.exists(data_path) or not os.path.exists(db_path):
    print("❌ Fehler: Die Dateien wurden nicht gefunden! Überprüfe die Pfade.")
else:
    print("✅ Dateien gefunden, lade Nullstellen...")

try:
    # Setze die Dateipfade für platt_zeros
    platt_zeros.data_location = data_path
    platt_zeros.db_location = db_path

    # Teste verschiedene Parameter für list_zeros()
    print("📌 Test: Wie viele Parameter benötigt list_zeros()?")

    if hasattr(platt_zeros, "list_zeros"):
        # Versuche aufzurufen ohne Parameter
        try:
            test = platt_zeros.list_zeros()
            print("✅ `list_zeros()` funktioniert ohne Parameter.")
        except TypeError as e:
            print(f"⚠️ `list_zeros()` benötigt Parameter: {e}")

        # Versuche mit einem Parameter (offset)
        try:
            test = platt_zeros.list_zeros(0)
            print("✅ `list_zeros(0)` funktioniert.")
        except TypeError as e:
            print(f"⚠️ `list_zeros(0)` benötigt mehr Parameter: {e}")

        # Versuche mit zwei Parametern (offset, block_number)
        try:
            test = platt_zeros.list_zeros(0, 1)
            print("✅ `list_zeros(0, 1)` funktioniert.")
        except TypeError as e:
            print(f"⚠️ `list_zeros(0, 1)` benötigt mehr Parameter: {e}")

        # Falls `list_zeros(0, 1)` geklappt hat, versuchen wir, Daten zu laden
        try:
            zeros_generator = platt_zeros.list_zeros(0, 1)
            zeros_list = [next(zeros_generator) for _ in range(10)]  # Erstmal 10 Nullstellen holen
            print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
            print("📊 Erste 10 Nullstellen:", zeros_list)
        except StopIteration:
            print("⚠️ Fehler: Keine weiteren Nullstellen in der Datei gefunden!")
        except Exception as e:
            print(f"❌ Fehler beim Laden der Nullstellen: {e}")

    else:
        print("❌ `list_zeros()` scheint nicht in `platt_zeros` zu existieren!")

except Exception as e:
    print(f"❌ Fehler im Hauptprogramm: {e}")
# Out:
# ✅ Dateien gefunden, lade Nullstellen...
# 📌 Test: Wie viele Parameter benötigt list_zeros()?
# ⚠️ `list_zeros()` benötigt Parameter: list_zeros() missing 3 required positional arguments: 'filename', 'offset', and 'block_number'
# ⚠️ `list_zeros(0)` benötigt mehr Parameter: list_zeros() missing 2 required positional arguments: 'offset' and 'block_number'
# ⚠️ `list_zeros(0, 1)` benötigt mehr Parameter: list_zeros() missing 1 required positional argument: 'block_number'
# ❌ Fehler beim Laden der Nullstellen: list_zeros() missing 1 required positional argument: 'block_number'

# %%
import sys
import os

# Füge den Pfad zu platt_zeros.py hinzu
sys.path.append("/content")

try:
    import platt_zeros
except ImportError:
    print("❌ Fehler: Modul 'platt_zeros' konnte nicht importiert werden!")

# Definiere die Dateipfade
data_path = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
db_path = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# Überprüfe, ob die Dateien existieren
if not os.path.exists(data_path) or not os.path.exists(db_path):
    print("❌ Fehler: Die Dateien wurden nicht gefunden! Überprüfe die Pfade.")
else:
    print("✅ Dateien gefunden, lade Nullstellen...")

try:
    # Setze die Dateipfade für platt_zeros
    platt_zeros.data_location = data_path
    platt_zeros.db_location = db_path

    # Richtig aufrufen mit drei Parametern
    print("📌 Lade Nullstellen mit `list_zeros(filename, offset, block_number)`...")

    filename = str(data_path)  # Datei mit Nullstellen als String
    offset = int(0)  # Sicherstellen, dass es eine Zahl ist
    block_number = int(1)  # Sicherstellen, dass es eine Zahl ist

    # Nullstellen laden
    zeros_generator = platt_zeros.list_zeros(filename, offset, block_number)
    zeros_list = list(zeros_generator)[:10]  # Erstmal 10 Nullstellen holen

    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list)

except StopIteration:
    print("⚠️ Fehler: Keine weiteren Nullstellen in der Datei gefunden!")
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# ✅ Dateien gefunden, lade Nullstellen...
# 📌 Lade Nullstellen mit `list_zeros(filename, offset, block_number)`...
# ❌ Fehler beim Laden der Nullstellen: unsupported operand type(s) for /: 'str' and 'str'

# %%
with open("/content/platt_zeros.py", "r") as f:
    for i, line in enumerate(f.readlines()):
        if "/" in line:  # Suche nach Divisionen
            print(f"🔎 Zeile {i+1}: {line.strip()}")
# Out:
# 🔎 Zeile 16: zeta_folder = Path('/home/lmfdb/data/zeros/zeta/').expanduser()
# 🔎 Zeile 17: data_location = zeta_folder / 'data'
# 🔎 Zeile 18: db_location = zeta_folder / 'index.db'
# 🔎 Zeile 46: - t_start/N_start: where to start the listing from. Either the
# 🔎 Zeile 57: infile = (data_location / filename).open('rb')
# 🔎 Zeile 123: infile = (data_location / filename).open('rb')

# %%
# ✅ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# ✅ Notwendige Bibliotheken importieren
import sys
from pathlib import Path

# ✅ Lade das platt_zeros Skript von GitHub
# !wget -O /content/platt_zeros.py https://raw.githubusercontent.com/LMFDB/lmfdb/main/lmfdb/zeros/zeta/platt_zeros.py

# ✅ Importiere platt_zeros
sys.path.append('/content')
import platt_zeros

# ✅ Setze die korrekten Pfade für Google Colab
data_location = Path("/content/drive/MyDrive/Aus Chrome gespeichert/")
db_location = Path("/content/drive/MyDrive/Aus Chrome gespeichert/index.db")

# ✅ Fix: Überschreibe die Pfade in `platt_zeros`
platt_zeros.data_location = data_location
platt_zeros.db_location = db_location

print("✅ Erfolgreich `data_location` und `db_location` überschrieben!")

# ✅ Teste, ob die Pfade korrekt gesetzt wurden
print("📌 Neuer `data_location`:", platt_zeros.data_location)
print("📌 Neuer `db_location`:", platt_zeros.db_location)

# ✅ Lade Nullstellen aus der Datei
filename = "zeros_30607946000.dat"  # Datei mit den Nullstellen
offset = 0  # Ab wo gelesen wird
block_number = 1  # Block-Nummer, um Nullstellen auszulesen

try:
    print("📌 Lade Nullstellen mit `list_zeros(filename, offset, block_number)`...")
    zeros_generator = platt_zeros.list_zeros(filename, offset, block_number)
    zeros_list = list(zeros_generator)[:10]  # Erstmal 10 Nullstellen holen
    print(f"✅ Erfolgreich {len(zeros_list)} Nullstellen geladen!")
    print("📊 Erste 10 Nullstellen:", zeros_list)
except Exception as e:
    print(f"❌ Fehler beim Laden der Nullstellen: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --2025-02-20 07:56:35--  https://raw.githubusercontent.com/LMFDB/lmfdb/main/lmfdb/zeros/zeta/platt_zeros.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6696 (6.5K) [text/plain]
# Saving to: ‘/content/platt_zeros.py’
#
# /content/platt_zero 100%[===================>]   6.54K  --.-KB/s    in 0s
#
# 2025-02-20 07:56:35 (49.5 MB/s) - ‘/content/platt_zeros.py’ saved [6696/6696]
#
# ✅ Erfolgreich `data_location` und `db_location` überschrieben!
# 📌 Neuer `data_location`: /content/drive/MyDrive/Aus Chrome gespeichert
# 📌 Neuer `db_location`: /content/drive/MyDrive/Aus Chrome gespeichert/index.db
# ...

# %%
# ✅ Notwendige Bibliotheken importieren
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from mpmath import mp

# ✅ Nullstellen extrahieren (nur Werte)
nullstellen = [float(z[1]) for z in zeros_list]  # Nur Werte behalten

# ✅ Abstände zwischen den Nullstellen berechnen
abstaende = np.diff(nullstellen)  # Differenzen berechnen
N_values = np.arange(1, len(abstaende) + 1)  # Index als N-Werte

# ✅ Fibonacci-Freese-Formel definieren
def fibonacci_freese(N, A, beta):
    return A * N**beta

# ✅ Curve-Fit zur Bestimmung der optimalen Parameter
initial_params = [1.5, 0.48]  # Erwartete Werte
params, _ = curve_fit(fibonacci_freese, N_values, abstaende, p0=initial_params)

# ✅ Extrahierte Parameter
A_opt, beta_opt = params
print(f"📊 Optimierte Parameter der Freese-Formel:")
print(f"🔹 Skalierungsfaktor A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_opt:.6f} (Erwartet: 0.484964)")

# ✅ Plot der Ergebnisse
plt.figure(figsize=(10, 5))
plt.scatter(N_values, abstaende, s=2, label="Gemessene Nullstellen-Abstände", color="blue")
plt.plot(N_values, fibonacci_freese(N_values, A_opt, beta_opt), label="Fit: Freese-Formel", color="red", linewidth=2)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("N")
plt.ylabel("Abstand L(N)")
plt.legend()
plt.grid()
plt.title("Log-Log-Plot der Nullstellen-Abstände mit Freese-Formel-Fit")
plt.show()
# Out:
# 📊 Optimierte Parameter der Freese-Formel:
# 🔹 Skalierungsfaktor A = 2.422833
# 🔹 Experimenteller Exponent beta = 0.323271 (Erwartet: 0.484964)

# %%
# ✅ Importiere die benötigten Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Lade Nullstellen-Daten (ersetze durch echte Nullstellen-Daten)
N_values = np.linspace(1, 3_000_000, num=100)  # Beispielwerte (ersetze mit echten N)
abstaende = 1.5 * N_values**0.48 + 0.05 * np.log(N_values) + 0.02 * np.sin(0.01 * N_values)  # Simulierte Abstände

# ✅ Definiere die ursprüngliche Freese-Formel mit log und Sinus-Korrektur
def freese_formula_extended(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Erste Schätzung für die Parameter
initial_params = [2.0, 0.48, 0.1, 0.01, 0.01, 0]  # (A, beta, C, B, omega, phi)

# ✅ Curve-Fit für die erweiterte Freese-Formel mit log + Sinus-Korrektur
params_opt, _ = curve_fit(freese_formula_extended, N_values, abstaende, p0=initial_params)

# ✅ Ergebnisse extrahieren
A_opt, beta_opt, C_opt, B_opt, omega_opt, phi_opt = params_opt

# ✅ Ergebnisse ausgeben
print(f"📊 Optimierte Parameter der erweiterten Freese-Formel:")
print(f"🔹 Skalierungsfaktor A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_opt:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Korrekturterm C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")

# ✅ Visualisierung
plt.figure(figsize=(10, 5))
plt.scatter(N_values, abstaende, label="Echte Daten", color="blue", alpha=0.5)
plt.plot(N_values, freese_formula_extended(N_values, *params_opt), label="Freese-Formel mit Korrekturen", color="red", linewidth=2)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("N (Index der Nullstelle)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Echte Daten vs. Modell")
plt.legend()
plt.grid()
plt.show()
# Out:
# 📊 Optimierte Parameter der erweiterten Freese-Formel:
# 🔹 Skalierungsfaktor A = 1.500000
# 🔹 Experimenteller Exponent beta = 0.480000 (Erwartet: 0.484964)
# 🔹 Logarithmischer Korrekturterm C = 0.050000
# 🔹 Sinus-Amplitude B = 0.020000
# 🔹 Sinus-Frequenz omega = 0.010000
# 🔹 Sinus-Phase phi = -0.000194

# %%
# ✅ Installiere benötigte Pakete
# !pip install numpy scipy matplotlib tqdm

# ✅ Importiere Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from tqdm import tqdm

# ✅ Lade die Datei mit 2 Millionen Nullstellen (Odlyzko)
url = "https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6"
file_path = "/content/zeros6.txt"

# Falls Datei nicht existiert, herunterladen
import os
if not os.path.exists(file_path):
    # !wget -O {file_path} {url}

# ✅ Lade die Nullstellen aus der Datei
def load_zeros(file_path, max_zeros=2000000):
    with open(file_path, "r") as f:
        zeros = np.array([float(line.strip()) for line in f.readlines()[:max_zeros]])
    return zeros

# ✅ Lade 2 Millionen Nullstellen
zeros = load_zeros(file_path)
print(f"✅ {len(zeros)} Nullstellen erfolgreich geladen!")

# ✅ Berechne die Kohärenzlängen (Abstände zwischen Nullstellen)
abstaende = np.diff(zeros)

# ✅ Definiere die erweiterte Fibonacci-Freese-Formel
def fibonacci_freese(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Bereite Daten für Curve Fit vor
N_values = np.arange(1, len(abstaende) + 1)

# ✅ Starte Curve Fit mit besseren Startwerten
initial_params = [1.5, 0.48, 0.05, 0.02, 0.01, 0]
params, _ = curve_fit(fibonacci_freese, N_values, abstaende, p0=initial_params)

# ✅ Extrahiere optimierte Parameter
A_opt, beta_opt, C_opt, B_opt, omega_opt, phi_opt = params

# ✅ Ausgabe der Ergebnisse
print("\n📊 Optimierte Parameter der erweiterten Fibonacci-Freese-Formel (2 Mio Nullstellen):")
print(f"🔹 Skalierungsfaktor A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_opt:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Korrekturterm C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")

# ✅ Visualisierung der Fit-Kurve
plt.figure(figsize=(10, 5))
plt.scatter(N_values[:10000], abstaende[:10000], s=1, label="Echte Kohärenzlängen", alpha=0.5)
plt.plot(N_values[:10000], fibonacci_freese(N_values[:10000], *params), color='r', lw=2, label="Angepasste Fibonacci-Freese-Formel")
plt.xlabel("Index N")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Erweiterte Fibonacci-Freese-Formel mit 2 Mio Nullstellen")
plt.legend()
plt.grid()
plt.show()
# Out:
# ...
# --2025-02-20 08:29:02--  https://www-users.cse.umn.edu/~odlyzko/zeta_tables/zeros6
# Resolving www-users.cse.umn.edu (www-users.cse.umn.edu)... 134.84.66.195
# Connecting to www-users.cse.umn.edu (www-users.cse.umn.edu)|134.84.66.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36018936 (34M)
# Saving to: ‘/content/zeros6.txt’
#
# /content/zeros6.txt 100%[===================>]  34.35M  60.7MB/s    in 0.6s
#
# 2025-02-20 08:29:03 (60.7 MB/s) - ‘/content/zeros6.txt’ saved [36018936/36018936]
#
# ✅ 2000000 Nullstellen erfolgreich geladen!
#
# 📊 Optimierte Parameter der erweiterten Fibonacci-Freese-Formel (2 Mio Nullstellen):
# 🔹 Skalierungsfaktor A = -0.108912
# 🔹 Experimenteller Exponent beta = 0.174481 (Erwartet: 0.484964)
# 🔹 Logarithmischer Korrekturterm C = 0.128136
# 🔹 Sinus-Amplitude B = -0.000178
# 🔹 Sinus-Frequenz omega = 0.009867
# 🔹 Sinus-Phase phi = 185.840483

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Fibonacci-Freese-Formel (Standard)
def fibonacci_freese(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# Lade 2M- und 3M-Daten
N_2M, abstaende_2M = lade_nullstellen("/content/drive/MyDrive/zeros_2M.txt")
N_3M, abstaende_3M = lade_nullstellen("/content/drive/MyDrive/zeros_3M.txt")

# Fit für 2M-Daten
params_2M, _ = curve_fit(fibonacci_freese, N_2M, abstaende_2M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
A_2M, beta_2M, C_2M, B_2M, omega_2M, phi_2M = params_2M

# Fit für 3M-Daten
params_3M, _ = curve_fit(fibonacci_freese, N_3M, abstaende_3M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
A_3M, beta_3M, C_3M, B_3M, omega_3M, phi_3M = params_3M

# Ergebnisse ausgeben
print("\n📊 Optimierte Parameter für 2M-Nullstellen:")
print(f"🔹 Skalierungsfaktor A = {A_2M:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_2M:.6f} (Erwartet: 0.484964)")

print("\n📊 Optimierte Parameter für 3M-Nullstellen:")
print(f"🔹 Skalierungsfaktor A = {A_3M:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_3M:.6f} (Erwartet: 0.484964)")

# Plot Beta-Verlauf über verschiedene Nullstellenmengen
plt.figure(figsize=(8,6))
plt.bar(["2M Nullstellen", "3M Nullstellen"], [beta_2M, beta_3M], color=['blue', 'green'])
plt.axhline(0.484964, color='red', linestyle='dashed', label="Erwarteter Fibonacci-Exponent")
plt.xlabel("Datenmenge")
plt.ylabel("Beta-Wert")
plt.title("Vergleich der Fibonacci-Freese-Exponenten für 2M und 3M Nullstellen")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-7d91fdf2fed4> in <cell line: 0>()
#       8
#       9 # Lade 2M- und 3M-Daten
# ---> 10 N_2M, abstaende_2M = lade_nullstellen("/content/drive/MyDrive/zeros_2M.txt")
#      11 N_3M, abstaende_3M = lade_nullstellen("/content/drive/MyDrive/zeros_3M.txt")
#      12
#
# NameError: name 'lade_nullstellen' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Funktion zum Laden der Nullstellen aus einer Datei
def lade_nullstellen(dateipfad):
    try:
        with open(dateipfad, "r") as file:
            nullstellen = np.array([float(line.strip()) for line in file])
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende
    except Exception as e:
        print(f"❌ Fehler beim Laden der Nullstellen aus {dateipfad}: {e}")
        return None, None

# ✅ Fibonacci-Freese-Formel (Standardversion)
def fibonacci_freese(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Dateipfade in Google Drive (Bitte anpassen falls nötig)
pfad_2M = "/content/drive/MyDrive/zeros_2M.txt"
pfad_3M = "/content/drive/MyDrive/zeros_3M.txt"

# ✅ Lade Nullstellen-Daten
N_2M, abstaende_2M = lade_nullstellen(pfad_2M)
N_3M, abstaende_3M = lade_nullstellen(pfad_3M)

if N_2M is not None and N_3M is not None:
    # ✅ Curve-Fitting für 2M Nullstellen
    params_2M, _ = curve_fit(fibonacci_freese, N_2M, abstaende_2M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
    A_2M, beta_2M, C_2M, B_2M, omega_2M, phi_2M = params_2M

    # ✅ Curve-Fitting für 3M Nullstellen
    params_3M, _ = curve_fit(fibonacci_freese, N_3M, abstaende_3M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
    A_3M, beta_3M, C_3M, B_3M, omega_3M, phi_3M = params_3M

    # ✅ Ergebnisse ausgeben
    print("\n📊 **Optimierte Parameter für 2M-Nullstellen:**")
    print(f"🔹 Skalierungsfaktor A = {A_2M:.6f}")
    print(f"🔹 Experimenteller Exponent beta = {beta_2M:.6f} (Erwartet: 0.484964)")
    print(f"🔹 Logarithmischer Korrekturterm C = {C_2M:.6f}")
    print(f"🔹 Sinus-Amplitude B = {B_2M:.6f}")
    print(f"🔹 Sinus-Frequenz omega = {omega_2M:.6f}")
    print(f"🔹 Sinus-Phase phi = {phi_2M:.6f}")

    print("\n📊 **Optimierte Parameter für 3M-Nullstellen:**")
    print(f"🔹 Skalierungsfaktor A = {A_3M:.6f}")
    print(f"🔹 Experimenteller Exponent beta = {beta_3M:.6f} (Erwartet: 0.484964)")
    print(f"🔹 Logarithmischer Korrekturterm C = {C_3M:.6f}")
    print(f"🔹 Sinus-Amplitude B = {B_3M:.6f}")
    print(f"🔹 Sinus-Frequenz omega = {omega_3M:.6f}")
    print(f"🔹 Sinus-Phase phi = {phi_3M:.6f}")

    # ✅ Vergleichsdiagramm erstellen
    plt.figure(figsize=(8,6))
    plt.bar(["2M Nullstellen", "3M Nullstellen"], [beta_2M, beta_3M], color=['blue', 'green'])
    plt.axhline(0.484964, color='red', linestyle='dashed', label="Erwarteter Fibonacci-Exponent")
    plt.xlabel("Datenmenge")
    plt.ylabel("Beta-Wert")
    plt.title("Vergleich der Fibonacci-Freese-Exponenten für 2M und 3M Nullstellen")
    plt.legend()
    plt.show()
else:
    print("⚠️ Fehler beim Laden der Nullstellen-Daten. Überprüfe die Dateipfade!")
# Out:
# ❌ Fehler beim Laden der Nullstellen aus /content/drive/MyDrive/zeros_2M.txt: [Errno 2] No such file or directory: '/content/drive/MyDrive/zeros_2M.txt'
# ❌ Fehler beim Laden der Nullstellen aus /content/drive/MyDrive/zeros_3M.txt: [Errno 2] No such file or directory: '/content/drive/MyDrive/zeros_3M.txt'
# ⚠️ Fehler beim Laden der Nullstellen-Daten. Überprüfe die Dateipfade!

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import sys
import sqlite3
import struct
from pathlib import Path

# ✅ PLATT-Import vorbereiten
platt_path = "/content/platt_zeros.py"

try:
    import platt_zeros
except ImportError:
    print("❌ `platt_zeros` nicht gefunden! Stelle sicher, dass das Platt-Skript heruntergeladen wurde.")
    sys.exit(1)

# ✅ Funktion zum Laden der 2M Nullstellen aus der .txt Datei
def lade_nullstellen_txt(dateipfad):
    try:
        with open(dateipfad, "r") as file:
            nullstellen = np.array([float(line.strip()) for line in file])
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende
    except Exception as e:
        print(f"❌ Fehler beim Laden der Nullstellen aus {dateipfad}: {e}")
        return None, None

# ✅ Funktion zum Laden der 3M Nullstellen aus der Platt `.dat` Datei
def lade_nullstellen_platt(db_path, data_path, num_blocks=10):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Lese den ersten Block-Index aus der Datenbank
        cursor.execute("SELECT block_number FROM zero_blocks ORDER BY block_number LIMIT ?", (num_blocks,))
        blocks = cursor.fetchall()
        conn.close()

        if not blocks:
            print("❌ Keine Blöcke gefunden!")
            return None, None

        # Lade Nullstellen für die ersten `num_blocks` Blöcke
        nullstellen = []
        for block_number in blocks:
            block = block_number[0]
            block_zeros = list(platt_zeros.list_zeros(data_path, offset=0, block_number=block))
            nullstellen.extend(block_zeros)

        nullstellen = np.array(nullstellen)
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende

    except Exception as e:
        print(f"❌ Fehler beim Laden der Platt Nullstellen: {e}")
        return None, None

# ✅ Fibonacci-Freese-Formel (Standardversion)
def fibonacci_freese(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Dateipfade in Google Drive (Bitte anpassen falls nötig)
pfad_2M = "/content/drive/MyDrive/zeros6.txt"
pfad_3M_data = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
pfad_3M_db = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# ✅ Lade Nullstellen-Daten für 2M & 3M
N_2M, abstaende_2M = lade_nullstellen_txt(pfad_2M)
N_3M, abstaende_3M = lade_nullstellen_platt(pfad_3M_db, pfad_3M_data, num_blocks=10)

if N_2M is not None and N_3M is not None:
    # ✅ Curve-Fitting für 2M Nullstellen
    params_2M, _ = curve_fit(fibonacci_freese, N_2M, abstaende_2M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
    A_2M, beta_2M, C_2M, B_2M, omega_2M, phi_2M = params_2M
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import sys
import sqlite3
import struct
from pathlib import Path

# ✅ PLATT-Import vorbereiten
platt_path = "/content/platt_zeros.py"

try:
    import platt_zeros
except ImportError:
    print("❌ `platt_zeros` nicht gefunden! Stelle sicher, dass das Platt-Skript heruntergeladen wurde.")
    sys.exit(1)

# ✅ Funktion zum Laden der 2M Nullstellen aus der .txt Datei
def lade_nullstellen_txt(dateipfad):
    try:
        with open(dateipfad, "r") as file:
            nullstellen = np.array([float(line.strip()) for line in file])
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende
    except Exception as e:
        print(f"❌ Fehler beim Laden der Nullstellen aus {dateipfad}: {e}")
        return None, None

# ✅ Funktion zum Laden der 3M Nullstellen aus der Platt `.dat` Datei
def lade_nullstellen_platt(db_path, data_path, num_blocks=10):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Lese den ersten Block-Index aus der Datenbank
        cursor.execute("SELECT block_number FROM zero_blocks ORDER BY block_number LIMIT ?", (num_blocks,))
        blocks = cursor.fetchall()
        conn.close()

        if not blocks:
            print("❌ Keine Blöcke gefunden!")
            return None, None

        # Lade Nullstellen für die ersten `num_blocks` Blöcke
        nullstellen = []
        for block_number in blocks:
            block = block_number[0]
            block_zeros = list(platt_zeros.list_zeros(data_path, offset=0, block_number=block))
            nullstellen.extend(block_zeros)

        nullstellen = np.array(nullstellen)
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende

    except Exception as e:
        print(f"❌ Fehler beim Laden der Platt Nullstellen: {e}")
        return None, None

# ✅ Fibonacci-Freese-Formel (Standardversion)
def fibonacci_freese(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Dateipfade in Google Drive (Bitte anpassen falls nötig)
pfad_2M = "/content/drive/MyDrive/zeros6.txt"
pfad_3M_data = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"
pfad_3M_db = "/content/drive/MyDrive/Aus Chrome gespeichert/index.db"

# ✅ Lade Nullstellen-Daten für 2M & 3M
N_2M, abstaende_2M = lade_nullstellen_txt(pfad_2M)
N_3M, abstaende_3M = lade_nullstellen_platt(pfad_3M_db, pfad_3M_data, num_blocks=10)

if N_2M is not None and N_3M is not None:
    # ✅ Curve-Fitting für 2M Nullstellen
    params_2M, _ = curve_fit(fibonacci_freese, N_2M, abstaende_2M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
    A_2M, beta_2M, C_2M, B_2M, omega_2M, phi_2M = params_2M

    # ✅ Curve-Fitting für 3M Nullstellen
    params_3M, _ = curve_fit(fibonacci_freese, N_3M, abstaende_3M, p0=[1.5, 0.48, 0.05, 0.02, 0.01, 0])
    A_3M, beta_3M, C_3M, B_3M, omega_3M, phi_3M = params_3M
# Out:
# ❌ Fehler beim Laden der Platt Nullstellen: no such table: zero_blocks
# ❌ Fehler beim Laden der Platt Nullstellen: no such table: zero_blocks

# %%
# ✅ Importiere die benötigten Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# ✅ Lade Nullstellen-Daten (Echte Daten oder Simulation)
def lade_nullstellen_txt(dateipfad):
    try:
        with open(dateipfad, "r") as file:
            nullstellen = np.array([float(line.strip()) for line in file])
        abstaende = np.diff(nullstellen)  # Abstand zwischen Nullstellen berechnen
        return np.arange(1, len(abstaende) + 1), abstaende
    except Exception as e:
        print(f"❌ Fehler beim Laden der Nullstellen aus {dateipfad}: {e}")
        return None, None

# ✅ Fibonacci-Freese-Formel mit log und Sinus-Korrektur
def fibonacci_freese_extended(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Initiale Schätzung der Parameter
initial_params = [1.5, 0.48, 0.1, 0.01, 0.01, 0]  # (A, beta, C, B, omega, phi)

# ✅ Pfade zu den echten Nullstellen-Dateien
pfad_2M = "/content/drive/MyDrive/zeros6.txt"
pfad_3M = "/content/drive/MyDrive/Aus Chrome gespeichert/zeros_30607946000.dat"  # Muss mit platt_zeros.py geladen werden

# ✅ Lade die 2M Nullstellen (Echte Daten)
N_2M, abstaende_2M = lade_nullstellen_txt(pfad_2M)

# ✅ Simuliere Daten für 3M falls Platt-Import fehlschlägt
N_3M = np.linspace(1, 3_000_000, num=100)  # Simulierte N-Werte
abstaende_3M = 1.5 * N_3M**0.48 + 0.05 * np.log(N_3M) + 0.02 * np.sin(0.01 * N_3M)

# ✅ Curve-Fit für 2M Nullstellen
if N_2M is not None:
    params_2M, _ = curve_fit(fibonacci_freese_extended, N_2M, abstaende_2M, p0=initial_params)
    A_2M, beta_2M, C_2M, B_2M, omega_2M, phi_2M = params_2M

    # ✅ Ergebnisse für 2M ausgeben
    print("\n📊 **Optimierte Parameter für 2M-Nullstellen:**")
    print(f"🔹 Skalierungsfaktor A = {A_2M:.6f}")
    print(f"🔹 Experimenteller Exponent beta = {beta_2M:.6f} (Erwartet: 0.484964)")
    print(f"🔹 Logarithmischer Korrekturterm C = {C_2M:.6f}")
    print(f"🔹 Sinus-Amplitude B = {B_2M:.6f}")
    print(f"🔹 Sinus-Frequenz omega = {omega_2M:.6f}")
    print(f"🔹 Sinus-Phase phi = {phi_2M:.6f}")

# ✅ Curve-Fit für 3M Nullstellen (Simulation)
params_3M, _ = curve_fit(fibonacci_freese_extended, N_3M, abstaende_3M, p0=initial_params)
A_3M, beta_3M, C_3M, B_3M, omega_3M, phi_3M = params_3M

# ✅ Ergebnisse für 3M ausgeben
print("\n📊 **Optimierte Parameter für 3M-Nullstellen (Simulation):**")
print(f"🔹 Skalierungsfaktor A = {A_3M:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_3M:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Korrekturterm C = {C_3M:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_3M:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_3M:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_3M:.6f}")

# ✅ Visualisierung für beide
plt.figure(figsize=(10, 5))
plt.scatter(N_2M, abstaende_2M, label="Echte 2M Daten", color="blue", alpha=0.5)
plt.plot(N_2M, fibonacci_freese_extended(N_2M, *params_2M), label="Fit für 2M Daten", color="red", linewidth=2)

plt.scatter(N_3M, abstaende_3M, label="Simulierte 3M Daten", color="green", alpha=0.5)
plt.plot(N_3M, fibonacci_freese_extended(N_3M, *params_3M), label="Fit für 3M Daten", color="orange", linewidth=2)

plt.xscale("log")
plt.yscale("log")
plt.xlabel("N (Index der Nullstelle)")
plt.ylabel("Kohärenzlänge L(N)")
plt.title("Vergleich: Echte 2M vs. Simulierte 3M Daten")
plt.legend()
plt.grid()
plt.show()
# Out:
# 📊 **Optimierte Parameter für 2M-Nullstellen:**
# 🔹 Skalierungsfaktor A = -0.109425
# 🔹 Experimenteller Exponent beta = 0.174273 (Erwartet: 0.484964)
# 🔹 Logarithmischer Korrekturterm C = 0.128298
# 🔹 Sinus-Amplitude B = 0.000175
# 🔹 Sinus-Frequenz omega = 0.009996
# 🔹 Sinus-Phase phi = 6.792916
#
# 📊 **Optimierte Parameter für 3M-Nullstellen (Simulation):**
# 🔹 Skalierungsfaktor A = 1.500000
# 🔹 Experimenteller Exponent beta = 0.480000 (Erwartet: 0.484964)
# 🔹 Logarithmischer Korrekturterm C = 0.050000
# 🔹 Sinus-Amplitude B = 0.020000
# 🔹 Sinus-Frequenz omega = 0.010000
# 🔹 Sinus-Phase phi = -0.000130
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
print(os.path.exists("/content/drive/MyDrive/Aus Chrome gespeichert/index.db"))
# Out:
# True

# %%
zeros_gen = list_zeros("zeros_30607946000.dat", 0, 0)  # Offset=0, Block=0
first_zeros = list(zeros_gen)[:10]  # Extrahiere die ersten 10 Nullstellen
print("📊 Erste 10 Nullstellen:", first_zeros)
# Out:
# 📊 Erste 10 Nullstellen: [(4763824896449970177, mpf('4.816313705014181323390415114809487631955675781')), (4763824896449970178, mpf('4.90008371460902690043903754656951321102017419')), (4763824896449970179, mpf('9.811748902699669693442995617862504704293151787')), (4763824896449970180, mpf('12.98687589036948469523803279414362222987323117')), (4763824896449970181, mpf('17.33633187638149599786337995833625595406230619')), (4763824896449970182, mpf('23.58109361060761056254963881527544698754105819')), (4763824896449970183, mpf('28.85683921333264765211595253335094339608570965')), (4763824896449970184, mpf('29.49228116294582537016214117140075887439037953')), (4763824896449970185, mpf('35.7309497863555622632297600038588372723150788')), (4763824896449970186, mpf('39.96111651598278223978823491239717892751116392'))]

# %%
# ✅ Importiere benötigte Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from mpmath import mp

# ✅ Lade die echten Nullstellen (Index ignorieren, nur Werte extrahieren)
def lade_nullstellen(nullstellen_liste):
    return np.array([float(mp.nstr(z[1], 15)) for z in nullstellen_liste])  # Konvertiere zu Float

# ✅ Berechne die Abstände zwischen aufeinanderfolgenden Nullstellen
def berechne_abstaende(nullstellen):
    return np.diff(nullstellen)

# ✅ Erweiterte Freese-Formel mit Korrekturen
def freese_formula_extended(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Nullstellen & Abstände für 2M und 3M laden
N_3M = np.arange(1, len(lade_nullstellen(first_zeros)) + 1)  # Index als x-Werte
abstaende_3M = berechne_abstaende(lade_nullstellen(first_zeros))  # Abstand als y-Werte

# ✅ Erste Schätzung für die Parameter
initial_params = [1.5, 0.48, 0.05, 0.02, 0.01, 0]

# ✅ Curve-Fit für die 3M-Daten
params_opt_3M, _ = curve_fit(freese_formula_extended, N_3M, abstaende_3M, p0=initial_params)

# ✅ Ergebnisse extrahieren
A_opt, beta_opt, C_opt, B_opt, omega_opt, phi_opt = params_opt_3M

# ✅ Optimierte Parameter für 3M ausgeben
print(f"📊 Optimierte Parameter der erweiterten Fibonacci-Freese-Formel (3 Mio Nullstellen):")
print(f"🔹 Skalierungsfaktor A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_opt:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Korrekturterm C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")

# ✅ Visualisierung: Vergleich der echten Abstände mit dem Fit
# ✅ Importiere benötigte Bibliotheken
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from mpmath import mp

# ✅ Lade die echten Nullstellen (Index ignorieren, nur Werte extrahieren)
def lade_nullstellen(nullstellen_liste):
    return np.array([float(mp.nstr(z[1], 15)) for z in nullstellen_liste])  # Konvertiere zu Float

# ✅ Berechne die Abstände zwischen aufeinanderfolgenden Nullstellen
def berechne_abstaende(nullstellen):
    return np.diff(nullstellen)

# ✅ Erweiterte Freese-Formel mit Korrekturen
def freese_formula_extended(N, A, beta, C, B, omega, phi):
    return A * N**beta + C * np.log(N) + B * np.sin(omega * N + phi)

# ✅ Nullstellen & Abstände für 2M und 3M laden
N_3M = np.arange(1, len(lade_nullstellen(first_zeros)) + 1)  # Index als x-Werte
abstaende_3M = berechne_abstaende(lade_nullstellen(first_zeros))  # Abstand als y-Werte

# ✅ Erste Schätzung für die Parameter
initial_params = [1.5, 0.48, 0.05, 0.02, 0.01, 0]

# ✅ Curve-Fit für die 3M-Daten
params_opt_3M, _ = curve_fit(freese_formula_extended, N_3M, abstaende_3M, p0=initial_params)

# ✅ Ergebnisse extrahieren
A_opt, beta_opt, C_opt, B_opt, omega_opt, phi_opt = params_opt_3M

# ✅ Optimierte Parameter für 3M ausgeben
print(f"📊 Optimierte Parameter der erweiterten Fibonacci-Freese-Formel (3 Mio Nullstellen):")
print(f"🔹 Skalierungsfaktor A = {A_opt:.6f}")
print(f"🔹 Experimenteller Exponent beta = {beta_opt:.6f} (Erwartet: 0.484964)")
print(f"🔹 Logarithmischer Korrekturterm C = {C_opt:.6f}")
print(f"🔹 Sinus-Amplitude B = {B_opt:.6f}")
print(f"🔹 Sinus-Frequenz omega = {omega_opt:.6f}")
print(f"🔹 Sinus-Phase phi = {phi_opt:.6f}")

# ✅ Visualisierung: Vergleich der echten Abstände mit dem Fit
plt.figure(figsize=(10, 5))
plt.scatter(N_3M, abstaende_3M, label="Echte Daten (3M)", color="blue", alpha=0.5)
plt.plot(N_3M, freese_formula_extended(N_3M, *params_opt_3M), label="Fit (3M)", color="red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-76e21e4cac13> in <cell line: 0>()
#      25
#      26 # ✅ Curve-Fit für die 3M-Daten
# ---> 27 params_opt_3M, _ = curve_fit(freese_formula_extended, N_3M, abstaende_3M, p0=initial_params)
#      28
#      29 # ✅ Ergebnisse extrahieren
#
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     998             raise TypeError(f"The number of func parameters={n} must not"
#     999                             f" exceed the number of data points={ydata.size}")
# -> 1000         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1001         popt, pcov, infodict, errmsg, ier = res
#    1002         ysize = len(infodict['fvec'])
#
# ...
